# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os

# %%
unique_chairs = np.load('unique_chair_images.npy')

# %%
chairs = np.load('chair_images.npy')

# %%
for chair in chairs[:10]:
    plt.imshow(chair[-4])
    plt.show()
    plt.close()

# %%
import matplotlib.pyplot as plt

from skimage.feature import hog
from skimage import data, exposure

for chair in chairs[:10]:
    f, axes = plt.subplots(1, 12, figsize=(12,1))
    for i in range(12):
        image = chair[i]
        feature = hog(image, orientations=8, pixels_per_cell=(128, 64),cells_per_block=(1, 1))
        axes[i].bar(range(16), feature)
    plt.show()
    
    
# for image in chairs[0]:
#     feature = hog(image, orientations=8, pixels_per_cell=(128, 128),cells_per_block=(1, 1))
#     plt.bar(range(8), feature)
#     plt.show()
#     plt.close()
    
# for image in chairs[1]:
#     feature = hog(image, orientations=8, pixels_per_cell=(128, 128),cells_per_block=(1, 1))
#     plt.bar(range(8), feature)
#     plt.show()
#     plt.close()
# Out:
# /home/weizhen/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
chair_hogs = []
for chair in chairs[:10]:
    f, axes = plt.subplots(1, 12, figsize=(12,1))
    for i in range(12):
        image = chair[i]
        feature = hog(image, orientations=8, pixels_per_cell=(128, 64),cells_per_block=(1, 1))
        axes[i].bar(range(16), feature)
    plt.show()

# %%
plt.imshow(chairs[0][1])
plt.show()
plt.imshow(chairs[1][1])
plt.show()
plt.imshow(chairs[2][5])
plt.show()

# %%
import matplotlib.pyplot as plt

from skimage.feature import hog
from skimage import data, exposure

image = chairs[10][10]

fd, hog_image = hog(image, orientations=8, pixels_per_cell=(4, 4),
                    cells_per_block=(1, 1), visualise=True)

feature = hog(image, orientations=8, pixels_per_cell=(128, 64),cells_per_block=(1, 1))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
plt.show()
# Out:
# /home/weizhen/anaconda3/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
np.mean(fd.ravel())
# Out:
# 0.017822249612603244

# %%
hog_image_rescaled.shape
# Out:
# (128, 128)

# %%
feature
# Out:
# array([ 0.52011764,  0.01011518,  0.01165171,  0.05249331,  0.05611113,
#         0.01341076,  0.03312529,  0.30297178,  0.33006354,  0.06718111,
#         0.03626323,  0.07767298,  0.10826477,  0.03785347,  0.07265557,
#         0.27003961])
